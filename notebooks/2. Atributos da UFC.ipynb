# %%
import pandas as pd
# %matplotlib inline
pd.set_option('display.max_colwidth', 0)

# %% [markdown]
# # Número de assistência estudantil

# %%
df = pd.read_csv('../Dados/numeros-assistencia-ao-estudante.csv', na_values='-', encoding='utf-8')

# %%
df.head()
# Out:
#                                        ESPECIFICAÇÃO  2003  2004  2005  2006  \
# 0                   Nº de Residências Universitarias   NaN   NaN   NaN   NaN
# 1     Nº de Alunos Residentes (Fortaleza e Interior)   207   214   229   221
# 2                  Nº de Auxílio Residentes (Alunos)   NaN   NaN   NaN   NaN
# 3  Nº de Ajuda de Custo (Alunos)-Participação de ...   NaN   NaN   NaN   NaN
# 4                Nº de Bolsas de Iniciação Acadêmica   NaN   NaN   NaN   NaN
#
#    2007  2008  2009  2010  2011  2012  2013
# 0   NaN   NaN    15    16    16    14    11
# 1   250   284   288   416   458   535   622
# 2   NaN   NaN   NaN   416   458   535   622
# 3   NaN  1161  2552  3648  3782  3695  4273
# 4   NaN   NaN   500   580   826   756   900

# %%
print df[[u'ESPECIFICAÇÃO', '2003', '2004', '2005', '2006', '2007']].to_latex(na_rep='-')
# Out:
# \begin{tabular}{llrrrrr}
# \toprule
# {} &                                          ESPECIFICAÇÃO &  2003 &  2004 &  2005 &  2006 &  2007 \\
# \midrule
# 0 &  Nº de Residências Universitarias & - & - & - & - & - \\
# 1 &  Nº de Alunos Residentes (Fortaleza e Interior) &  207 &  214 &  229 &  221 &  250 \\
# 2 &  Nº de Auxílio Residentes (Alunos) & - & - & - & - & - \\
# 3 &  Nº de Ajuda de Custo (Alunos)-Participação de eventos & - & - & - & - & - \\
# 4 &  Nº de Bolsas de Iniciação Acadêmica & - & - & - & - & - \\
# 5 &  Nº de Bolsas de Incentivo ao Desporto & - & - & - & - & - \\
# 6 &  Nº de Acompanhamento Psicológico & - & - & - & - & - \\
# \bottomrule
# \end{tabular}

# %%
print df[[u'ESPECIFICAÇÃO', '2008', '2009', '2010', '2011', '2012', '2013']].to_latex(na_rep='-')
# Out:
# \begin{tabular}{llrrrrrr}
# \toprule
# {} &                                          ESPECIFICAÇÃO &  2008 &  2009 &  2010 &  2011 &  2012 &  2013 \\
# \midrule
# 0 &  Nº de Residências Universitarias & - &  15 &  16 &  16 &  14 &  11 \\
# 1 &  Nº de Alunos Residentes (Fortaleza e Interior) &  284 &  288 &  416 &  458 &  535 &  622 \\
# 2 &  Nº de Auxílio Residentes (Alunos) & - & - &  416 &  458 &  535 &  622 \\
# 3 &  Nº de Ajuda de Custo (Alunos)-Participação de eventos &  1161 &  2552 &  3648 &  3782 &  3695 &  4273 \\
# 4 &  Nº de Bolsas de Iniciação Acadêmica & - &  500 &  580 &  826 &  756 &  900 \\
# 5 &  Nº de Bolsas de Incentivo ao Desporto & - & - &  30 &  50 &  100 &  100 \\
# 6 &  Nº de Acompanhamento Psicológico & - &  259 &  179 &  120 &  190 &  423 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### evolução

# %%
df.set_index(u'ESPECIFICAÇÃO').T.plot(figsize=(14, 8))

# %% [markdown]
# # Número de bolsas da graduação

# %%
df = pd.read_csv('../Dados/numeros-bolsas-graduacao.csv', na_values='-', encoding='utf-8')

# %%
df.columns
# Out:
# Index([u'ESPECIFICAÇÃO',          u'2003',          u'2004',          u'2005',
#                 u'2006',          u'2007',          u'2008',          u'2009',
#                 u'2010',          u'2011',          u'2012',          u'2013'],
#       dtype='object')

# %%
print df[[u'ESPECIFICAÇÃO', '2007', '2008', '2009', '2010', '2011', '2012', '2013']].to_latex(na_rep="-")
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# {} &                               ESPECIFICAÇÃO &  2007 &  2008 &  2009 &  2010 &  2011 &  2012 &  2013 \\
# \midrule
# 0  &                    Aprendizagem Cooperativa &     - &     - &    98 &   226 &   250 &   250 &   233 \\
# 1  &                        Apoio Administrativo &     - &     - &     - &   100 &   100 &   200 &   170 \\
# 2  &                              Cultura e Arte &     - &     - &    64 &    64 &    64 &    80 &   100 \\
# 3  &                                    Desporto &     - &     - &     - &    30 &    50 &   100 &   100 \\
# 4  &                                    Extensão &     - &     - &   274 &   378 &   618 &   670 &   650 \\
# 5  &                Iniciação Científica - PIBIC &   665 &   726 &   782 &   769 &   942 &   925 &   914 \\
# 6  &                  Iniciação Acadêmica - PRAE &     - &     - &   500 &   580 &   826 &   756 &   900 \\
# ...

# %%
df.head()
# Out:
#               ESPECIFICAÇÃO  2003  2004  2005  2006  2007  2008  2009  2010  \
# 0  Aprendizagem Cooperativa   NaN   NaN   NaN   NaN   NaN   NaN    98   226
# 1      Apoio Administrativo   NaN   NaN   NaN   NaN   NaN   NaN   NaN   100
# 2            Cultura e Arte   NaN   NaN   NaN   NaN   NaN   NaN    64    64
# 3                  Desporto   NaN   NaN   NaN   NaN   NaN   NaN   NaN    30
# 4                  Extensão   NaN   NaN   NaN   NaN   NaN   NaN   274   378
#
#    2011  2012  2013
# 0   250   250   233
# 1   100   200   170
# 2    64    80   100
# 3    50   100   100
# 4   618   670   650

# %%
df[:5].set_index(u'ESPECIFICAÇÃO').T.plot(figsize=(10, 10), ylim=[0, 1000])

# %%
df[5:].set_index(u'ESPECIFICAÇÃO').T.plot(figsize=(10, 10), ylim=[0, 1000])

# %% [markdown]
# # Porcentagem de discentes de graduação com bolsa

# %%
df = pd.read_csv('../Dados/pct-discentes-com-bolsa.csv', encoding='utf-8', na_values='-')

# %%
df.head()
# Out:
#                                     ESPECIFICAÇÃO  2003  2004  2005  2006  \
# 0  Iniciação Científica - PIBIC e PET(Sesu e UFC)   NaN   NaN   NaN   NaN
# 1                              Bolsa de Monitoria   NaN   NaN   NaN   NaN
#
#    2007  2008  2009  2010  2011  2012  2013
# 0   NaN   4.5   4.6   4.7   5.2   5.4  5.43
# 1   NaN   5.2   5.7   7.7   7.9   7.2  6.81

# %%
print df[[u'ESPECIFICAÇÃO', '2008', '2009', '2010', '2011', '2012', '2013']].to_latex(na_rep='-')
# Out:
# \begin{tabular}{llrrrrrr}
# \toprule
# {} &                                   ESPECIFICAÇÃO &  2008 &  2009 &  2010 &  2011 &  2012 &  2013 \\
# \midrule
# 0 &  Iniciação Científica - PIBIC e PET(Sesu e UFC) &   4.5 &   4.6 &   4.7 &   5.2 &   5.4 &  5.43 \\
# 1 &                              Bolsa de Monitoria &   5.2 &   5.7 &   7.7 &   7.9 &   7.2 &  6.81 \\
# \bottomrule
# \end{tabular}

# %%
df.set_index(u'ESPECIFICAÇÃO').T.plot(figsize=(6, 5), ylim=[0, 100])

# %% [markdown]
# # Números de vagas casas de cultura

# %%
df = pd.read_csv('../Dados/numeros-vagas-casas-de-cultura.csv', encoding='utf-8', na_values='-')

# %%
df.head()
# Out:
#             ESPECIFICAÇÃO  2003  2004  2005  2006  2007  2008  2009  2010  \
# 0       Teste de Admissão  2151  1719  1670  1706  1550  1766  1691  1268
# 1        Teste de Seleção  1636  1194  1344  1706   572  2363  2021  1949
# 2  Nº Alunos Matriculados  6197  6051  5646  5796  5867  5452  5806  5579
# 3  Nº Alunos Concludentes  1492  1410  1308  1316   945  1380  1447  1149
#
#    2011  2012  2013
# 0  1276  1078  1124
# 1  1803  1494  1407
# 2  4892  4014  3462
# 3  1166   936  1067

# %%
print df[[u'ESPECIFICAÇÃO', '2003', '2004', '2005', '2006', '2007']].to_latex(na_rep='-')
# Out:
# \begin{tabular}{llrrrrr}
# \toprule
# {} &           ESPECIFICAÇÃO &  2003 &  2004 &  2005 &  2006 &  2007 \\
# \midrule
# 0 &       Teste de Admissão &  2151 &  1719 &  1670 &  1706 &  1550 \\
# 1 &        Teste de Seleção &  1636 &  1194 &  1344 &  1706 &   572 \\
# 2 &  Nº Alunos Matriculados &  6197 &  6051 &  5646 &  5796 &  5867 \\
# 3 &  Nº Alunos Concludentes &  1492 &  1410 &  1308 &  1316 &   945 \\
# \bottomrule
# \end{tabular}

# %%
print df[[u'ESPECIFICAÇÃO', '2008', '2009', '2010', '2011', '2012', '2013']].to_latex(na_rep='-')
# Out:
# \begin{tabular}{llrrrrrr}
# \toprule
# {} &           ESPECIFICAÇÃO &  2008 &  2009 &  2010 &  2011 &  2012 &  2013 \\
# \midrule
# 0 &       Teste de Admissão &  1766 &  1691 &  1268 &  1276 &  1078 &  1124 \\
# 1 &        Teste de Seleção &  2363 &  2021 &  1949 &  1803 &  1494 &  1407 \\
# 2 &  Nº Alunos Matriculados &  5452 &  5806 &  5579 &  4892 &  4014 &  3462 \\
# 3 &  Nº Alunos Concludentes &  1380 &  1447 &  1149 &  1166 &   936 &  1067 \\
# \bottomrule
# \end{tabular}

# %%
df.set_index(u'ESPECIFICAÇÃO').T.plot(figsize=(10, 10))

# %% [markdown]
# # Orçamento da UFC

# %%
df = pd.read_csv('../Dados/orcamento-ufc.csv', encoding='utf-8', na_values='-')

# %%
df.head()
# Out:
#             ESPECIFICAÇÃO  2003  2004  2005  2006  2007    2008    2009  \
# 0                Previsão   NaN   NaN   NaN   NaN   NaN  804.05  748.06
# 1               Executado   NaN   NaN   NaN   NaN   NaN  771.74  774.84
# 2  Executado/Previsão (%)   NaN   NaN   NaN   NaN   NaN   95.98  103.58
#
#      2010    2011    2012     2013
# 0  901.89  934.76  974.62  1116.86
# 1  917.41  927.40  977.95  1119.66
# 2  101.72   99.21  100.34   100.25

# %%
print df[[u'ESPECIFICAÇÃO', '2008', '2009', '2010', '2011', '2012', '2013']].to_latex(na_rep='-')
# Out:
# \begin{tabular}{llrrrrrr}
# \toprule
# {} &           ESPECIFICAÇÃO &    2008 &    2009 &    2010 &    2011 &    2012 &     2013 \\
# \midrule
# 0 &                Previsão &  804.05 &  748.06 &  901.89 &  934.76 &  974.62 &  1116.86 \\
# 1 &               Executado &  771.74 &  774.84 &  917.41 &  927.40 &  977.95 &  1119.66 \\
# 2 &  Executado/Previsão (\%) &   95.98 &  103.58 &  101.72 &   99.21 &  100.34 &   100.25 \\
# \bottomrule
# \end{tabular}

# %%
df.set_index(u'ESPECIFICAÇÃO').T.plot(figsize=(8, 6))

# %% [markdown]
# # Área construída da UFC

# %%
df = pd.read_csv('../Dados/area-construida-ufc.csv', encoding='utf-8', na_values='-')

# %%
df.head()
# Out:
#               ESPECIFICAÇÃO    2003    2004    2005    2006    2007    2008  \
# 0  Área Construída (mil m2)  233.63  233.63  233.63  235.14  235.14  262.73
#
#      2009    2010    2011    2012    2013
# 0  277.48  291.31  307.57  317.23  340.67

# %%
print df[[u'ESPECIFICAÇÃO', '2003', '2004', '2005', '2006', '2007']].to_latex(na_rep='-')
# Out:
# \begin{tabular}{llrrrrr}
# \toprule
# {} &             ESPECIFICAÇÃO &    2003 &    2004 &    2005 &    2006 &    2007 \\
# \midrule
# 0 &  Área Construída (mil m2) &  233.63 &  233.63 &  233.63 &  235.14 &  235.14 \\
# \bottomrule
# \end{tabular}

# %%
print df[[u'ESPECIFICAÇÃO', '2008', '2009', '2010', '2011', '2012', '2013']].to_latex(na_rep='-')
# Out:
# \begin{tabular}{llrrrrrr}
# \toprule
# {} &             ESPECIFICAÇÃO &    2008 &    2009 &    2010 &    2011 &    2012 &    2013 \\
# \midrule
# 0 &  Área Construída (mil m2) &  262.73 &  277.48 &  291.31 &  307.57 &  317.23 &  340.67 \\
# \bottomrule
# \end{tabular}

# %%
df.set_index(u'ESPECIFICAÇÃO').T.plot(ylim=[0, 400])

# %% [markdown]
# # Indicadores do TCU

# %%
df = pd.read_csv('../Dados/indicadores-tcu-ufc.csv', encoding='utf-8', na_values='-')

# %%
df = df.set_index('COMPONENTES DOS INDICADORES DE DESEMPENHO').applymap(lambda x: '%.2f' % x)

# %%
print df[['2008', '2009']].to_latex(na_rep='-')
# Out:
# \begin{tabular}{lll}
# \toprule
# {} &          2008 &          2009 \\
# \midrule
# COMPONENTES DOS INDICADORES DE DESEMPENHO                   &               &               \\
# AE – Aluno Equivalente da UFC1                              &  34023.00 &  33557.62 \\
# ATI – Aluno em Tempo Integral                               &  21212.00 &  21461.92 \\
# AgE – Aluno Equivalente de Graduação                        &  28080.00 &  27074.62 \\
# ApgTI – Aluno da Pós-Graduação em Tempo Integral            &  5615.00 &  6075.00 \\
# ArTI – Aluno de Residência em Tempo Integral                &  328.00 &  408.00 \\
# AgTI – Aluno de Graduação em Tempo Integral                 &  15269.00 &  14978.92 \\
# Ag – Aluno de Graduação                                     &  20991.00 &  21289.00 \\
# Apg – Aluno de Pós-Graduação                                &  2808.00 &  3038.00 \\
# Ar – Aluno de Residência Médica                             &  164.00 &  204.00 \\
# ...

# %%
print df[['2010', '2011']].to_latex(na_rep='-')
# Out:
# \begin{tabular}{lll}
# \toprule
# {} &          2010 &          2011 \\
# \midrule
# COMPONENTES DOS INDICADORES DE DESEMPENHO                   &               &               \\
# AE – Aluno Equivalente da UFC1                              &  37908.26 &  40708.72 \\
# ATI – Aluno em Tempo Integral                               &  23307.93 &  25035.20 \\
# AgE – Aluno Equivalente de Graduação                        &  31631.26 &  33018.72 \\
# ApgTI – Aluno da Pós-Graduação em Tempo Integral            &  5839.00 &  7308.00 \\
# ArTI – Aluno de Residência em Tempo Integral                &  438.00 &  382.00 \\
# AgTI – Aluno de Graduação em Tempo Integral                 &  17030.93 &  17345.20 \\
# Ag – Aluno de Graduação                                     &  22538.00 &  25971.00 \\
# Apg – Aluno de Pós-Graduação                                &  2920.00 &  3654.00 \\
# Ar – Aluno de Residência Médica                             &  219.00 &  191.00 \\
# ...

# %%
print df[['2012', '2013']].to_latex(na_rep='-')
# Out:
# \begin{tabular}{lll}
# \toprule
# {} &          2012 &          2013 \\
# \midrule
# COMPONENTES DOS INDICADORES DE DESEMPENHO                   &               &               \\
# AE – Aluno Equivalente da UFC1                              &  41144.35 &  42443.53 \\
# ATI – Aluno em Tempo Integral                               &  26330.48 &  26466.34 \\
# AgE – Aluno Equivalente de Graduação                        &  32468.35 &  34247.53 \\
# ApgTI – Aluno da Pós-Graduação em Tempo Integral            &  8268.00 &  7760.00 \\
# ArTI – Aluno de Residência em Tempo Integral                &  408.00 &  436.00 \\
# AgTI – Aluno de Graduação em Tempo Integral                 &  17654.48 &  18270.34 \\
# Ag – Aluno de Graduação                                     &  26956.00 &  27433.00 \\
# Apg – Aluno de Pós-Graduação                                &  4134.00 &  3880.00 \\
# Ar – Aluno de Residência Médica                             &  204.00 &  218.00 \\
# ...
