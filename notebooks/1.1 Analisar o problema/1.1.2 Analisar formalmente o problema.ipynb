# %% [markdown]
# # Descrição

# %% [markdown]
# Descrição das entidades, seus atributos, seus relacionamentos e definição do problema.

# %% [markdown]
# ----

# %% [markdown]
# [TODO] Adicionar diagrama ER

# %% [markdown]
# # 1 Entidades

# %% [markdown]
# ## 1.1 Discente

# %% [markdown]
# ### 1.1.1 Data de nascimento

# %% [markdown]
# ### 1.1.2 Grau de escolaridade dos pais

# %% [markdown]
# ## 1.2 Docente

# %% [markdown]
# ### 1.2.1 Lattes

# %% [markdown]
# ## 1.3 Instituição de ensino

# %% [markdown]
# ## 1.4 Turma

# %% [markdown]
# ### 1.4.1 Horários

# %% [markdown]
# ### 1.4.2 Local

# %% [markdown]
# ### 1.4.3 Data de início

# %% [markdown]
# ### 1.4.4 Data de fim

# %% [markdown]
# ### 1.4.5 Professor

# %% [markdown]
# ### 1.4.6 Alunos

# %% [markdown]
# ### 1.4.7 Componente Curricular

# %% [markdown]
# ## 1.5 Componente Curricular

# %% [markdown]
# ### 1.5.1 Carga horária

# %% [markdown]
# ### 1.5.2 Regime({semestral, anual})

# %% [markdown]
# # 2 Evasão

# %% [markdown]
# Interrupção de um processo de aprendizado

# %% [markdown]
# ## 2.1 Escopo

# %% [markdown]
# 1. Curso
# 2. IES
# 3. Sistema de ensino

# %% [markdown]
# ## 2.2 Tempo

# %% [markdown]
# 1. Definitivo
# 2. Stopout
#   2.1 Duração

# %% [markdown]
# ## 2.3 Pós interrupção

# %% [markdown]
# 1. Irrelevante
# 2. Mudança de IES
# 3. Mudança de área de conhecimento
# 4. Mudança de regime de dedicação({partial-time, full-time})

# %% [markdown]
# # 3 Métricas

# %% [markdown]
# ## 3.1 Taxa de sucesso na graduação
# ver:
#
# [ref] <a href="../../Documentos/Manual-Indicadores-TCU.pdf">Manual-Indicadores-TCU.pdf</a>
# [ref] <a href="../../Documentos/diretrizesreuni.pdf">diretrizesreuni.pdf</a>

# %% [markdown]
# ## 3.2 Taxa de evasão anual
# daonde tirei isso? documentos do instituto lobo?
